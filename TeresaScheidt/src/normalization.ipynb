# %%
import os
import os.path
import numpy as np
import glob
import matplotlib.pyplot as plt
import preprocessing_functions as pre

import skimage.io 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# define image paths
images = glob.glob(r"..\Data\8bitImages\*\*.png") # define imagefolder
norm_images = [i.replace('8bitImages','Normalized_Images') for i in images] # define goal folder

# %%
# save normalized images
for i,o in zip(images,norm_images):
   pre.normalize(i,o)

# %%
# normalize and stack images

(images_norm, mean_norm, std_norm) = pre.norm_and_stack(images)

images_unnorm = pre.unnormalize(images_norm, mean_norm, std_norm)

# %%
# unnormalize images
images_unnorm = images_unnorm.astype(np.uint8)

# %%
# plot normalized images
plt.figure(figsize=(7,7))

for i in range(12):
    plt.subplot(3,4,i+1)    
    plt.imshow(images_norm[:,:,i])

plt.show()

# %%
# plot unnormalized images
plt.figure(figsize=(7,7)) 

for i in range(12):
    plt.subplot(3,4,i+1)    
    plt.imshow(images_unnorm[:,:,i])

plt.show()

# %%
# plot original images
coll = skimage.io.imread_collection(images[0:12])
skimage.io.imshow_collection(coll)
