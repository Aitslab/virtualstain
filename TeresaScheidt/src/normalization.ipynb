# %%
import os
import os.path
import numpy as np
import glob
import matplotlib.pyplot as plt
import preprocessing_functions as pre
import training_functions as training
# Out:
# Using TensorFlow backend.

# %%
images = glob.glob(r"C:\Users\tsche\Desktop\Master\2. Semester\Project Staining\16bitImages\*d0.png")

# %%
imagestack = pre.stack_images(images)

# %%
(norm_stack, mean, std) = pre.norm_stack(imagestack)

# %%
mean = np.mean(imagestack)
std = np.std(imagestack)
norm_im = (imagestack - mean)/std

# %%
unnorm_stack = pre.unnormalize(norm_stack, mean, std)

# %%
plt.imshow(imagestack[0]-unnorm_stack[0])

# %%
plt.figure(figsize=(10,15)) 

for p in range(5):
    plt.subplot(5,3,1+3*p)    
    plt.imshow(imagestack[p,:,:], cmap='gray')

    plt.subplot(5,3,2+3*p)    
    plt.imshow(norm_stack[p,:,:], cmap='gray')

    plt.subplot(5,3,3+3*p) 
    plt.imshow(unnorm_stack[p,:,:], cmap='gray')


plt.show()
