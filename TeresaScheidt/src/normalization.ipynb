# %%
import os
import os.path
import numpy as np
import glob
import matplotlib.pyplot as plt
import preprocessing_functions as pre

import skimage.io 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# define image paths
images = glob.glob(r"C:\Users\tsche\Desktop\Master\2. Semester\Project Staining\conversion\Sample_16bitpng_to_Teresa\*.png")
norm_images = [i.replace('Sample_16bitpng_to_Teresa','normalized_images') for i in images]

# %%
# save normalized images
for i,o in zip(images,norm_images):
   pre.normalize(i,o)

# %%
# normalize and stack images

(images_norm, mean_norm, std_norm) = pre.norm_and_stack(images)

images_unnorm = pre.unnormalize(images_norm, mean_norm, std_norm)

# %%
# unnormalize images
images_unnorm = images_unnorm.astype(np.uint8)

# %%
# plot normalized images
plt.figure(figsize=(7,7))

for i in range(12):
    plt.subplot(3,4,i+1)    
    plt.imshow(images_norm[:,:,3*i:3*i+3])

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# plot unnormalized images
plt.figure(figsize=(7,7)) 

for i in range(12):
    plt.subplot(3,4,i+1)    
    plt.imshow(images_unnorm[:,:,3*i:3*i+3])

plt.show()

# %%
# plot original images
coll = skimage.io.imread_collection(images)
skimage.io.imshow_collection(coll)
